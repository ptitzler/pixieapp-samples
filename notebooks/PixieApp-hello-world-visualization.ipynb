# %% [markdown]
# ## What are PixieApps?
#
# PixieApps are Python classes used to write UI elements for your analytics, and they run directly in a Jupyter notebook. [Learn more](https://ibm-cds-labs.github.io/pixiedust/pixieapps.html)

# %%
# uncomment the following line to install/upgrade the PixieDust library
# ! pip install pixiedust --user --upgrade
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-cds-labs/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-cds-labs/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.0.6</span>
#         </div>

# %% [markdown]
# ## Hello World with Data Visualization
#
# The following PixieApp displays a pie chart for a simple dataframe.

# %%
#Create dataframe
df = SQLContext(sc).createDataFrame(
[(2010, 'Camping Equipment', 3, 200),(2010, 'Camping Equipment', 10, 200),(2010, 'Golf Equipment', 1, 240),
 (2010, 'Mountaineering Equipment', 1, 348),(2010, 'Outdoor Protection',2,200),(2010, 'Personal Accessories', 2, 200),
 (2011, 'Camping Equipment', 4, 489),(2011, 'Golf Equipment', 5, 234),(2011, 'Mountaineering Equipment',2, 123),
 (2011, 'Outdoor Protection', 4, 654),(2011, 'Personal Accessories', 2, 234),(2012, 'Camping Equipment', 5, 876),
 (2012, 'Golf Equipment', 5, 200),(2012, 'Mountaineering Equipment', 3, 156),(2012, 'Outdoor Protection', 5, 200),
 (2012, 'Personal Accessories', 3, 345),(2013, 'Camping Equipment', 8, 987),(2013, 'Golf Equipment', 5, 434),
 (2013, 'Mountaineering Equipment', 3, 278),(2013, 'Outdoor Protection', 8, 134),(2013,'Personal Accessories',4, 200)],
 ["year","zone","unique_customers", "revenue"])

# %%
from pixiedust.display.app import *
@PixieApp
class HelloWorldPixieAppWithDataChart:
    @route()
    def mainScreen(self):
        return """
        <!-- displays the data frame as a pie chart -->
        <div pd_entity pd_options="handlerId=pieChart;keyFields=zone;valueFields=unique_customers;aggregation=SUM;rowCount=500"/>
"""
    
#run the app
HelloWorldPixieAppWithDataChart().run(df, runInDialog='false')
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;3ab807b5&quot;, &quot;command&quot;: &quot;display(HelloWorldPixieAppWithDataChart_instance,runInDialog=&apos;false&apos;,handlerId=&apos;__main___HelloWorldPixieAppWithDataChart_id&apos;,cell_id=&apos;644B79895B374E0EA9CC82488240682B&apos;,nostore_pixiedust=&apos;true&apos;,nostore_cw=&apos;1827&apos;,org_params=&apos;runInDialog,handlerId,nostore_pixiedust&apos;,nostore_bokeh=&apos;true&apos;)&quot;, &quot;options&quot;: {&quot;runInDialog&quot;: &quot;false&quot;, &quot;cell_id&quot;: &quot;644B79895B374E0EA9CC82488240682B&quot;, &quot;org_params&quot;: &quot;runInDialog,handlerId,nostore_pixiedust&quot;, &quot;nostore_cw&quot;: &quot;1827&quot;, &quot;handlerId&quot;: &quot;__main___HelloWorldPixieAppWithDataChart_id&quot;, &quot;nostore_bokeh&quot;: &quot;true&quot;, &quot;nostore_pixiedust&quot;: &quot;true&quot;, &quot;showchrome&quot;: &quot;true&quot;}}">
# ...

# %% [markdown]
# ### How we added the simple visualization to the app
#
# * Create a new notebook cell and define your data frame

# %%
#Create dataframe
df = SQLContext(sc).createDataFrame(
[(2010, 'Camping Equipment', 3, 200),(2010, 'Camping Equipment', 10, 200),(2010, 'Golf Equipment', 1, 240),
 (2010, 'Mountaineering Equipment', 1, 348),(2010, 'Outdoor Protection',2,200),(2010, 'Personal Accessories', 2, 200),
 (2011, 'Camping Equipment', 4, 489),(2011, 'Golf Equipment', 5, 234),(2011, 'Mountaineering Equipment',2, 123),
 (2011, 'Outdoor Protection', 4, 654),(2011, 'Personal Accessories', 2, 234),(2012, 'Camping Equipment', 5, 876),
 (2012, 'Golf Equipment', 5, 200),(2012, 'Mountaineering Equipment', 3, 156),(2012, 'Outdoor Protection', 5, 200),
 (2012, 'Personal Accessories', 3, 345),(2013, 'Camping Equipment', 8, 987),(2013, 'Golf Equipment', 5, 434),
 (2013, 'Mountaineering Equipment', 3, 278),(2013, 'Outdoor Protection', 8, 134),(2013,'Personal Accessories',4, 200)],
 ["year","zone","unique_customers", "revenue"])

# %% [markdown]
# * Display the data frame `display(df)`
# * Select the desired chart type (e.g. Chart type: `Pie Chart`, options &gt; keys: `zone`,  options &gt; values: `unique_customers` )
# * Enable medata view (Main menu: `View` &gt; `Cell Toolbar` &gt;  `Edit Metadata`)
# * Click `Edit Metadata` on the right hand side of the `display(df)` cell
# * Copy the `displayParams` that look like this
#  ```
#  "handlerId": "pieChart",
#  "keyFields": "zone",
#  "valueFields": "unique_customers",
#  "aggregation": "SUM",
#  "rowCount": "500"
#  ```
#  (instructions continue below the chart)

# %%
display(df)
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;8c0842b9&quot;, &quot;command&quot;: &quot;display(df,cell_id=&apos;64A8F7174FA5433AA58651A480136C99&apos;,nostore_pixiedust=&apos;true&apos;,handlerId=&apos;pieChart&apos;,keyFields=&apos;zone&apos;,valueFields=&apos;unique_customers&apos;,aggregation=&apos;SUM&apos;,rowCount=&apos;500&apos;,clusterby=&apos;year&apos;,nostore_cw=&apos;1827&apos;,org_params=&apos;nostore_pixiedust&apos;,nostore_bokeh=&apos;true&apos;)&quot;, &quot;options&quot;: {&quot;nostore_bokeh&quot;: &quot;true&quot;, &quot;cell_id&quot;: &quot;64A8F7174FA5433AA58651A480136C99&quot;, &quot;org_params&quot;: &quot;nostore_pixiedust&quot;, &quot;aggregation&quot;: &quot;SUM&quot;, &quot;nostore_cw&quot;: &quot;1827&quot;, &quot;clusterby&quot;: &quot;year&quot;, &quot;rowCount&quot;: &quot;500&quot;, &quot;handlerId&quot;: &quot;pieChart&quot;, &quot;valueFields&quot;: &quot;unique_customers&quot;, &quot;keyFields&quot;: &quot;zone&quot;, &quot;nostore_
# ...

# %% [markdown]
# * Consolidate the paramters in a string with the following format: `handlerId=pieChart;keyFields=zone;valueFields=unique_customers;aggregation=SUM;rowCount=500`
# * Provide this string as `pd_options` value in your app
#   ```
#   <div pd_entity pd_options="handlerId=pieChart;keyFields=zone;valueFields=unique_customers;aggregation=SUM;rowCount=500"/>
#   ```
#
#   Result:
#
#
#   ```
# from pixiedust.display.app import *
# @PixieApp
# class HelloWorldPixieAppWithDataChart:
#     @route()
#     def mainScreen(self):
#         return """
#         <!-- displays the data frame as a pie chart -->
#         <div pd_entity pd_options="handlerId=pieChart;keyFields=zone;valueFields=unique_customers;aggregation=SUM;rowCount=500"/>
# """
#
# #run the app
# HelloWorldPixieAppWithDataChart().run(df, runInDialog='false')
#   ```
#
# Completed app:

# %%
from pixiedust.display.app import *
@PixieApp
class HelloWorldPixieAppWithDataChart:
    @route()
    def mainScreen(self):
        return """
        <!-- displays the data frame as a pie chart -->
        <div pd_entity pd_options="handlerId=pieChart;keyFields=zone;valueFields=unique_customers;aggregation=SUM;rowCount=500"/>
"""

#run the app
HelloWorldPixieAppWithDataChart().run(df, runInDialog='false')
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;b9cab9a8&quot;, &quot;command&quot;: &quot;display(HelloWorldPixieAppWithDataChart_instance,runInDialog=&apos;false&apos;,handlerId=&apos;__main___HelloWorldPixieAppWithDataChart_id&apos;,cell_id=&apos;0BAC8BBCA45D4ED2A24BC9AAC7B272DE&apos;,nostore_pixiedust=&apos;true&apos;,nostore_cw=&apos;1827&apos;,org_params=&apos;runInDialog,handlerId,nostore_pixiedust&apos;,nostore_bokeh=&apos;true&apos;)&quot;, &quot;options&quot;: {&quot;runInDialog&quot;: &quot;false&quot;, &quot;cell_id&quot;: &quot;0BAC8BBCA45D4ED2A24BC9AAC7B272DE&quot;, &quot;org_params&quot;: &quot;runInDialog,handlerId,nostore_pixiedust&quot;, &quot;nostore_cw&quot;: &quot;1827&quot;, &quot;handlerId&quot;: &quot;__main___HelloWorldPixieAppWithDataChart_id&quot;, &quot;nostore_bokeh&quot;: &quot;true&quot;, &quot;nostore_pixiedust&quot;: &quot;true&quot;, &quot;showchrome&quot;: &quot;true&quot;}}">
# ...
